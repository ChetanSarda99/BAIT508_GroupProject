# %%
#load datasets with pandas
import pandas as pd
#k10_file=pd.read_csv(r'C:\Users\sarda\Desktop\UBC\BAIT 508\GroupProject\data\2020_10K_item1_full.csv')
pf= pd.read_csv(r'C:\Users\sarda\Desktop\UBC\BAIT 508\GroupProject\data\public_firms.csv')

# %%
pf
# Out:
#          gvkey  fyear location              conm     ipodate   sic  prcc_c  \
# 0         1004   1994      USA          AAR CORP  1988/01/01  5080  13.375
# 1         1004   1995      USA          AAR CORP  1988/01/01  5080  22.000
# 2         1004   1996      USA          AAR CORP  1988/01/01  5080  30.250
# 3         1004   1997      USA          AAR CORP  1988/01/01  5080  38.750
# 4         1004   1998      USA          AAR CORP  1988/01/01  5080  23.875
# ...        ...    ...      ...               ...         ...   ...     ...
# 209207  345980   2019      USA  CONTEXTLOGIC INC  2020/12/16  5961     NaN
# 209208  345980   2020      USA  CONTEXTLOGIC INC  2020/12/16  5961  18.240
# 209209  347085   2018      SGP      KAROOOOO LTD  2021/04/01  7370     NaN
# 209210  347085   2019      SGP      KAROOOOO LTD  2021/04/01  7370     NaN
# 209211  347085   2020      SGP      KAROOOOO LTD  2021/04/01  7370     NaN
#
#               ch       ni     asset      sale       roa
# ...

# %%
#industry = [5080,5090]
industry_sector = pf[pf['sic'] has (50)]
#shows nans in data
# Out:
#   Cell In[1], line 2
#     industry_sector = pf[pf['sic'] has (50)]
#                          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
industry_sector
# Out:
#          gvkey  fyear location                         conm     ipodate   sic  \
# 0         1004   1994      USA                     AAR CORP  1988/01/01  5080
# 1         1004   1995      USA                     AAR CORP  1988/01/01  5080
# 2         1004   1996      USA                     AAR CORP  1988/01/01  5080
# 3         1004   1997      USA                     AAR CORP  1988/01/01  5080
# 4         1004   1998      USA                     AAR CORP  1988/01/01  5080
# ...        ...    ...      ...                          ...         ...   ...
# 203708  187714   2017      USA  WESCO AIRCRAFT HOLDINGS INC  2011/07/28  5080
# 203709  187714   2018      USA  WESCO AIRCRAFT HOLDINGS INC  2011/07/28  5080
# 203710  187714   2019      USA  WESCO AIRCRAFT HOLDINGS INC  2011/07/28  5080
# 204538  198255   2014      USA         WOD RETAIL SOLUTIONS         NaN  5090
# 204539  198255   2015      USA         WOD RETAIL SOLUTIONS         NaN  5090
#
# ...
